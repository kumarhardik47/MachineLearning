# %% [markdown]
# <a href="https://colab.research.google.com/github/kumarhardik47/MachineLearning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas
# Useful for Data Processing & Analysis
#
# Pandas DataFrame
# Pandas DataFrame is a two dimensional tabular data structure with labelled axis( rows and columns)

#import pandas library
import pandas as pd

#Creating Pandas DataFrame

#Lets import diabetes dataset from sklearn.

from sklearn.datasets import load_diabetes

diabetes_dataset = load_diabetes()
print(type(diabetes_dataset))
#print (diabetes_dataset)

#Create dataframe
diabetes_df = pd.DataFrame(diabetes_dataset.data, columns = diabetes_dataset.feature_names)

print(diabetes_df.head())
diabetes_df.shape

# %%
# Import data from a csv file

import pandas as pd

boston_df = pd.read_csv('/content/sample_data/HousingData.csv')

print(boston_df.head())
print(boston_df.shape)

# %%
# Create Dataframe with random values
import numpy as np
random_df = pd.DataFrame(np.random.rand(10,100))
#print(random_df)

#Inspecting a dataframe

#Find rows and columns
print(boston_df.shape)
print(boston_df.head())
print(boston_df.tail())

print(boston_df.info())

#Find missing values
print(boston_df.isnull().sum())


#diabetes_df

# %%
#print(diabetes_df.head())

#count unique occurene of values in a column
print(diabetes_df.value_counts('bmi'))

#Group the values based on the mean
print(diabetes_df.groupby('bmi').mean())

# %%
#Statistical Measures

#count of each column
print(boston_df.count())

#mean of each column
print(boston_df.mean())

#standard deviation
print(boston_df.std())

#min value of waech column
print(boston_df.min())

#max value of waech column
print(boston_df.max())


#####################ALL ABOVE COMBINED ###############

print(boston_df.describe())

# %%
#Manipulate a DataFrame
#

#add a column to a df
#boston_df['price'] = boston_dataset.target

#remove a column
boston_df.drop(index=0, axis=1) # 1st column  # to remove row, gice axis =0 or to remove column give axis =1

#locate a row using index value
boston_df.iloc[2]

#print 1st column of df
boston_df.iloc[:,0]

# %%
## CORRELATION -- it is findind the relation between different columns

# POSITIVE CORRELATION
# NEGATIVE CORRELATION

boston_df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.191178  0.401863 -0.054355  0.417130 -0.219150  0.354342
# ZN      -0.191178  1.000000 -0.531871 -0.037229 -0.513704  0.320800 -0.563801
# INDUS    0.401863 -0.531871  1.000000  0.059859  0.764866 -0.390234  0.638431
# CHAS    -0.054355 -0.037229  0.059859  1.000000  0.075097  0.104885  0.078831
# NOX      0.417130 -0.513704  0.764866  0.075097  1.000000 -0.302188  0.731548
# RM      -0.219150  0.320800 -0.390234  0.104885 -0.302188  1.000000 -0.247337
# AGE      0.354342 -0.563801  0.638431  0.078831  0.731548 -0.247337  1.000000
# DIS     -0.374166  0.656739 -0.711709 -0.093971 -0.769230  0.205246 -0.744844
# RAD      0.624765 -0.310919  0.604533  0.001468  0.611441 -0.209847  0.458349
# TAX      0.580595 -0.312371  0.731055 -0.032304  0.668023 -0.292048  0.509114
# PTRATIO  0.281110 -0.414046  0.390954 -0.111304  0.188933 -0.355501  0.269226
# ...
